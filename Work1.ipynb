# %% [markdown]
# <a href="https://colab.research.google.com/github/sabbar01-web/Homeworks/blob/main/Work1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1

# %%
x=float(input('x='))
y=(5*x-10)/(4-4*x-x**2)
print (y)
# Out:
# x=2
# -0.0

# %% [markdown]
# 2

# %%
import math
x=float(input('x='))
z=log10(x**3 + 4*sqrt(x) + 5)
print (z)
# Out:
# x=9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-2a4739c4ed3f> in <cell line: 0>()
#       1 from math import log
#       2 x=float(input('x='))
# ----> 3 z=log(x**3 + 4*(x)^1/2 + 5)
#       4 print (z)
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'float'
